# %% [markdown]
# # Part 1

# %%
# Importing libraries

import pandas as pd
import numpy as np
import os

# %%
#Defining path
path = r'/Users/richardniyongabo/Desktop/Tasks_4.6_richard'

# %%
# Import data

df_cust = pd.read_csv(os.path.join(path, 'customers.csv'), index_col = False)

# %%
# Checking output

df_cust.shape
# Out:
# (206209, 10)

# %%
df_cust.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %% [markdown]
# # Wrangle the data so that it follows consistent logic

# %%
# Renaming columns for easier reading

df_cust.rename(columns = {'Surnam': 'last_name'}, inplace=True)

# %%
df_cust.rename(columns = {'First Name': 'first_name'}, inplace=True)

# %%
df_cust.rename(columns = {'Gender': 'gender'}, inplace=True)

# %%
df_cust.rename(columns = {'STATE': 'state'}, inplace=True)

# %%
df_cust.rename(columns = {'Age': 'age'}, inplace=True)

# %%
df_cust.rename(columns = {'n_dependants': 'number_of_dependents'}, inplace=True)

# %%
df_cust.rename(columns = {'fam_status': 'marital_status'}, inplace=True)

# %%
df_cust.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependents marital_status  income
# 0                     3        married  165665
# 1                     0         single   59285
# 2                     2        married   99568
# 3                     0         single   42049
# 4                     1        married   40374

# %% [markdown]
# # Completing the fundamental data quality and consistency checks

# %%
# Checking for duplicates

df_cust[df_cust.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, number_of_dependents, marital_status, income]
# Index: []

# %%
# Finding missing values

df_cust.isnull().sum()
# Out:
# user_id                     0
# first_name              11259
# last_name                   0
# gender                      0
# state                       0
# age                         0
# date_joined                 0
# number_of_dependents        0
# marital_status              0
# income                      0
# dtype: int64

# %%
# Viewing missing values in first_name column

df_nan_fn = df_cust[df_cust['first_name'].isnull() == True]

# %%
df_nan_fn
# Out:
#         user_id first_name last_name  gender         state  age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         number_of_dependents marital_status  income
# ...

# %%
# Creating new df w/o first_name to check for duplicates

df_drop_fn = df_cust.drop(columns=['first_name'], axis=1)

# %%
df_drop_fn.head()
# Out:
#    user_id last_name  gender       state  age date_joined  \
# 0    26711  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Farley    Male       Idaho   35    1/1/2017
# 3   125935     Hicks  Female        Iowa   40    1/1/2017
# 4   130797   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependents marital_status  income
# 0                     3        married  165665
# 1                     0         single   59285
# 2                     2        married   99568
# 3                     0         single   42049
# 4                     1        married   40374

# %%
df_drop_fn[df_drop_fn.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, last_name, gender, state, age, date_joined, number_of_dependents, marital_status, income]
# Index: []

# %%
# There are no duplicates and missing data

# %%
# Checking for mixed data types

for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col)
# Out:
# first_name

# %%
# Examining data type for 'first_name' and reassigning to string

df_cust['first_name'].dtype
# Out:
# dtype('O')

# %%
df_cust['first_name'] = df_cust['first_name'].astype('str')

# %%
# Checking output

for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col)

# %%
df_cust.dtypes
# Out:
# user_id                  int64
# first_name              object
# last_name               object
# gender                  object
# state                   object
# age                      int64
# date_joined             object
# number_of_dependents     int64
# marital_status          object
# income                   int64
# dtype: object

# %%
# Checking output again

df_cust.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependents marital_status  income
# 0                     3        married  165665
# 1                     0         single   59285
# 2                     2        married   99568
# 3                     0         single   42049
# 4                     1        married   40374

# %% [markdown]
# # Combining customer data with the rest of the prepared Instacart data

# %%
# Importing ords_prods_merged data

ords_prods_merged = pd.read_pickle(os.path.join(path, 'orders_products_merged_ver2.pkl'))

# %%
# Checking output

ords_prods_merged.shape
# Out:
# (32434212, 21)

# %%
ords_prods_merged.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  Unnamed: 0  user_id  \
# 0         2       33120                  1          1     3355525   202279
# 1        26       33120                  5          0     2549350   153404
# 2       120       33120                 13          0      395303    23750
# 3       327       33120                  5          1      976751    58707
# 4       390       33120                 28          1     2764474   166654
#
#   eval_set  order_number  order_dow  order_hour_of_day  ...  new_customer  \
# 0    prior             3          5                  9  ...         False
# 1    prior             2          0                 16  ...         False
# 2    prior            11          6                  8  ...         False
# 3    prior            21          6                  9  ...         False
# 4    prior            48          0                 12  ...         False
#
#          product_name aisle_id  department_id  prices  _merge  \
# ...

# %%
# Shared key column is 'user_id'
# Checking data type for 'user_id' in both df's

ords_prods_merged['user_id'].dtype
# Out:
# dtype('int64')

# %%
df_cust['user_id'].dtype
# Out:
# dtype('int64')

# %%
# Merge the df's
# Inner merge smaller df_cust onto larger ords_prods_merge

df_full_merge = ords_prods_merged.merge(df_cust, on = 'user_id')

# %%
# Checking output

df_full_merge.shape
# Out:
# (32434212, 30)

# %%
df_full_merge.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  Unnamed: 0  user_id  \
# 0         2       33120                  1          1     3355525   202279
# 1    104690       33120                  2          1     3355530   202279
# 2    132412       33120                  1          1     3355528   202279
# 3   2808715       33120                  1          1     3355527   202279
# 4   2894949       33120                  5          0     3355523   202279
#
#   eval_set  order_number  order_dow  order_hour_of_day  ...  \
# 0    prior             3          5                  9  ...
# 1    prior             8          6                 10  ...
# 2    prior             6          5                  9  ...
# 3    prior             5          5                 13  ...
# 4    prior             1          5                  9  ...
#
#    busiest_period_of_day  first_name last_name  gender  state  age  \
# 0         Average orders        Paul   Coleman    Male  Idaho   57
# ...

# %%
df_full_merge.to_pickle(os.path.join(path, 'full_merge.pkl'))
