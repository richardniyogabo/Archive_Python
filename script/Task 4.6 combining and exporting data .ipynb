# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %%
#Defining path
path = r'/Users/richardniyongabo/Desktop/Tasks_4.6_richard'

# %%
print(os.path.join(path,'order_products_prior.csv' ))
# Out:
# /Users/richardniyongabo/Desktop/Tasks_4.6_richard/order_products_prior.csv

# %%
#Import data 1
df_orders_products = pd.read_pickle(os.path.join(path, 'orders_products_merged.pkl'))

# %%
#Checking data 1
df_orders_products.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  Unnamed: 0  user_id  \
# 0         2       33120                  1          1     3355525   202279
# 1         2       28985                  2          1     3355525   202279
# 2         2        9327                  3          0     3355525   202279
# 3         2       45918                  4          1     3355525   202279
# 4         2       30035                  5          0     3355525   202279
#
#   eval_set  order_number  order_dow  order_hour_of_day  \
# 0    prior             3          5                  9
# 1    prior             3          5                  9
# 2    prior             3          5                  9
# 3    prior             3          5                  9
# 4    prior             3          5                  9
#
#    days_since_prior_order  new_customer _merge
# 0                     8.0         False   both
# 1                     8.0         False   both
# ...

# %%
df_orders_products.shape
# Out:
# (32434489, 13)

# %%
#Importing data 2
df_products = pd.read_csv(os.path.join(path, 'products.csv'), index_col = False)

# %%
#Checking data 2
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_products.shape
# Out:
# (49693, 5)

# %% [markdown]
# # Merging Data

# %%
#Drop __merge
df_orders_products = df_orders_products.drop(columns = ['_merge'])

# %%
#Checking data 1
df_orders_products.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  Unnamed: 0  user_id  \
# 0         2       33120                  1          1     3355525   202279
# 1         2       28985                  2          1     3355525   202279
# 2         2        9327                  3          0     3355525   202279
# 3         2       45918                  4          1     3355525   202279
# 4         2       30035                  5          0     3355525   202279
#
#   eval_set  order_number  order_dow  order_hour_of_day  \
# 0    prior             3          5                  9
# 1    prior             3          5                  9
# 2    prior             3          5                  9
# 3    prior             3          5                  9
# 4    prior             3          5                  9
#
#    days_since_prior_order  new_customer
# 0                     8.0         False
# 1                     8.0         False
# 2                     8.0         False
# ...

# %%
#Merging
df_orders_products_merged = df_orders_products.merge(df_products, on = 'product_id', indicator = True)

# %%
#checking merged data 
df_orders_products_merged.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  Unnamed: 0  user_id  \
# 0         2       33120                  1          1     3355525   202279
# 1        26       33120                  5          0     2549350   153404
# 2       120       33120                 13          0      395303    23750
# 3       327       33120                  5          1      976751    58707
# 4       390       33120                 28          1     2764474   166654
#
#   eval_set  order_number  order_dow  order_hour_of_day  \
# 0    prior             3          5                  9
# 1    prior             2          0                 16
# 2    prior            11          6                  8
# 3    prior            21          6                  9
# 4    prior            48          0                 12
#
#    days_since_prior_order  new_customer        product_name  aisle_id  \
# 0                     8.0         False  Organic Egg Whites        86
# ...

# %%
df_orders_products_merged['_merge'].value_counts()
# Out:
# both          32434212
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_orders_products_merged.shape
# Out:
# (32434212, 17)

# %% [markdown]
# # Exporting data

# %%
# Exporting data to pkl
df_orders_products_merged.to_pickle(os.path.join(path, 'orders_products_merged.pkl'))
